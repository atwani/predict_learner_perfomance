# %%
import pandas as pd
myData=pd.read_excel('skill_builder_data.xlsx')

# %%
myData.head()
# Out:
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# 1  33022709         277618    64525          33150       51435         1
# 2  35450204         220674    70363          33159       51444         1
# 3  35450295         220674    70363          33110       51395         1
# 4  35450311         220674    70363          33196       51481         1
#
#    correct  attempt_count  ms_first_response tutor_mode  ... hint_count  \
# 0        1              1              32454      tutor  ...          0
# 1        1              1               4922      tutor  ...          0
# 2        0              2              25390      tutor  ...          0
# 3        1              1               4859      tutor  ...          0
# 4        0             14              19813      tutor  ...          3
#
#    hint_total  overlap_time  template_id answer_id  answer_text  first_action  \
# ...

# %%
myData2=myData[(myData['correct']==1)&(myData['attempt_count']==1)]

# %%
myData2.head()
# Out:
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# 1  33022709         277618    64525          33150       51435         1
# 3  35450295         220674    70363          33110       51395         1
# 5  35450555         220674    70363          33172       51457         1
# 6  35450573         220674    70363          33174       51459         1
#
#    correct  attempt_count  ms_first_response tutor_mode  ... hint_count  \
# 0        1              1              32454      tutor  ...          0
# 1        1              1               4922      tutor  ...          0
# 3        1              1               4859      tutor  ...          0
# 5        1              1              16031      tutor  ...          0
# 6        1              1              15047      tutor  ...          0
#
#    hint_total  overlap_time  template_id answer_id  answer_text  first_action  \
# ...

# %% [markdown]
# Assignment that was passed by most students on first attempt

# %%
myData2.assignment_id.value_counts()
# Out:
# 279733    13113
# 279732    12028
# 279728     7688
# 279730     7560
# 280036     6256
#           ...
# 275100        1
# 267416        1
# 277763        1
# 226950        1
# 217901        1
# Name: assignment_id, Length: 3281, dtype: int64

# %% [markdown]
# Assignment passed without a hint on first attempt

# %%
myData3=myData2=myData[(myData['correct']==1)&(myData['attempt_count']==1)& (myData['hint_count']==0)]

# %%
myData3.head()
# Out:
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# 1  33022709         277618    64525          33150       51435         1
# 3  35450295         220674    70363          33110       51395         1
# 5  35450555         220674    70363          33172       51457         1
# 6  35450573         220674    70363          33174       51459         1
#
#    correct  attempt_count  ms_first_response tutor_mode  ... hint_count  \
# 0        1              1              32454      tutor  ...          0
# 1        1              1               4922      tutor  ...          0
# 3        1              1               4859      tutor  ...          0
# 5        1              1              16031      tutor  ...          0
# 6        1              1              15047      tutor  ...          0
#
#    hint_total  overlap_time  template_id answer_id  answer_text  first_action  \
# ...

# %%
myData3.assignment_id.value_counts()
# Out:
# 279733    13113
# 279732    12028
# 279728     7688
# 279730     7560
# 280036     6256
#           ...
# 275100        1
# 267416        1
# 277763        1
# 226950        1
# 217901        1
# Name: assignment_id, Length: 3281, dtype: int64
