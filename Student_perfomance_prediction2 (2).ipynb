# %%
import pandas as pd
myData=pd.read_excel('skill_builder_data.xlsx',index_col=0)

# %%
myData.head()
# Out:
#           assignment_id  user_id  assistment_id  problem_id  original  \
# order_id
# 33022537         277618    64525          33139       51424         1
# 33022709         277618    64525          33150       51435         1
# 35450204         220674    70363          33159       51444         1
# 35450295         220674    70363          33110       51395         1
# 35450311         220674    70363          33196       51481         1
#
#           correct  attempt_count  ms_first_response tutor_mode answer_type  \
# order_id
# 33022537        1              1              32454      tutor     algebra
# 33022709        1              1               4922      tutor     algebra
# 35450204        0              2              25390      tutor     algebra
# 35450295        1              1               4859      tutor     algebra
# 35450311        0             14              19813      tutor     algebra
#
# ...

# %%
myData2=myData[(myData['correct']==1)&(myData['attempt_count']==1)]

# %%
myData2.head()
# Out:
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# 1  33022709         277618    64525          33150       51435         1
# 3  35450295         220674    70363          33110       51395         1
# 5  35450555         220674    70363          33172       51457         1
# 6  35450573         220674    70363          33174       51459         1
#
#    correct  attempt_count  ms_first_response tutor_mode  ... hint_count  \
# 0        1              1              32454      tutor  ...          0
# 1        1              1               4922      tutor  ...          0
# 3        1              1               4859      tutor  ...          0
# 5        1              1              16031      tutor  ...          0
# 6        1              1              15047      tutor  ...          0
#
#    hint_total  overlap_time  template_id answer_id  answer_text  first_action  \
# ...

# %% [markdown]
# Assignment that was passed by most students on first attempt

# %%
myData2.assignment_id.value_counts()
# Out:
# 279733    13113
# 279732    12028
# 279728     7688
# 279730     7560
# 280036     6256
#           ...
# 275100        1
# 267416        1
# 277763        1
# 226950        1
# 217901        1
# Name: assignment_id, Length: 3281, dtype: int64

# %% [markdown]
# Assignment passed without a hint on first attempt

# %%
myData3=myData2=myData[(myData['correct']==1)&(myData['attempt_count']==1)& (myData['hint_count']==0)]

# %%
myData3.head()
# Out:
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# 1  33022709         277618    64525          33150       51435         1
# 3  35450295         220674    70363          33110       51395         1
# 5  35450555         220674    70363          33172       51457         1
# 6  35450573         220674    70363          33174       51459         1
#
#    correct  attempt_count  ms_first_response tutor_mode  ... hint_count  \
# 0        1              1              32454      tutor  ...          0
# 1        1              1               4922      tutor  ...          0
# 3        1              1               4859      tutor  ...          0
# 5        1              1              16031      tutor  ...          0
# 6        1              1              15047      tutor  ...          0
#
#    hint_total  overlap_time  template_id answer_id  answer_text  first_action  \
# ...

# %%
myData3.assignment_id.value_counts()
# Out:
# 279733    13113
# 279732    12028
# 279728     7688
# 279730     7560
# 280036     6256
#           ...
# 275100        1
# 267416        1
# 277763        1
# 226950        1
# 217901        1
# Name: assignment_id, Length: 3281, dtype: int64

# %%
myData.order_id.unique()
# Out:
# array([33022537, 33022709, 35450204, ..., 38214195, 38214196, 38214198],
#       dtype=int64)

# %% [markdown]
# Check if there are null values

# %%
myData.isnull
# Out:
# <bound method DataFrame.isnull of           assignment_id  user_id  assistment_id  problem_id  original  \
# order_id
# 33022537         277618    64525          33139       51424         1
# 33022709         277618    64525          33150       51435         1
# 35450204         220674    70363          33159       51444         1
# 35450295         220674    70363          33110       51395         1
# 35450311         220674    70363          33196       51481         1
# ...                 ...      ...            ...         ...       ...
# 38214014         291495    96299          57830      108976         0
# 38214016         291495    96299          57843      109015         0
# 38214195         291503    96299          34577       54060         0
# 38214196         291503    96299          34577       54061         0
# 38214198         291503    96299          34577       54062         0
#
#           correct  attempt_count  ms_first_response tutor_mode answer_type  \
# ...

# %% [markdown]
# Drop null values

# %%
myData.dropna()
# Out:
# Empty DataFrame
# Columns: [assignment_id, user_id, assistment_id, problem_id, original, correct, attempt_count, ms_first_response, tutor_mode, answer_type, sequence_id, student_class_id, position, type, base_sequence_id, skill_id, skill_name, teacher_id, school_id, hint_count, hint_total, overlap_time, template_id, answer_id, answer_text, first_action, bottom_hint, opportunity, opportunity_original]
# Index: []
#
# [0 rows x 29 columns]

# %%
myData.head()
# Out:
#           assignment_id  user_id  assistment_id  problem_id  original  \
# order_id
# 33022537         277618    64525          33139       51424         1
# 33022709         277618    64525          33150       51435         1
# 35450204         220674    70363          33159       51444         1
# 35450295         220674    70363          33110       51395         1
# 35450311         220674    70363          33196       51481         1
#
#           correct  attempt_count  ms_first_response tutor_mode answer_type  \
# order_id
# 33022537        1              1              32454      tutor     algebra
# 33022709        1              1               4922      tutor     algebra
# 35450204        0              2              25390      tutor     algebra
# 35450295        1              1               4859      tutor     algebra
# 35450311        0             14              19813      tutor     algebra
#
# ...

# %%
myData.shape
# Out:
# (525534, 30)

# %%
myData.sort_values(by=['user_id'])
# Out:
#         order_id  assignment_id user_id  assistment_id  problem_id  original  \
# 0       33022537         277618   64525          33139       51424         1
# 350364  34892988         279732   64525          50387       89280         1
# 350363  34892988         279732   64525          50387       89280         1
# 350362  34892988         279732   64525          50387       89280         1
# 350361  34892988         279732   64525          50387       89280         1
# ...          ...            ...     ...            ...         ...       ...
# 175170  35108326         281003   64525          47169       85685         1
# 175169  35108326         281003   64525          47169       85685         1
# 175168  35108326         281003   64525          47169       85685         1
# 175262  34290399         280036   64525          47149       85665         1
# 525533  38214198         291503   64525          34577       54062         0
#
# ...

# %%
myData.dtypes
# Out:
# order_id                  int64
# assignment_id             int64
# user_id                  object
# assistment_id             int64
# problem_id                int64
# original                  int64
# correct                   int64
# attempt_count             int64
# ms_first_response         int64
# tutor_mode               object
# answer_type              object
# sequence_id               int64
# student_class_id          int64
# position                  int64
# type                     object
# base_sequence_id          int64
# skill_id                float64
# skill_name               object
# teacher_id                int64
# school_id                 int64
# hint_count                int64
# hint_total                int64
# overlap_time              int64
# template_id               int64
# answer_id               float64
# answer_text              object
# first_action              int64
# bottom_hint             float64
# opportunity               int64
# ...

# %% [markdown]
# Create a dataframe with columns of interest

# %%
myNewData=myData[['assignment_id','user_id','assistment_id','problem_id','original','correct','attempt_count','ms_first_response','hint_count','hint_total','overlap_time','first_action']]

# %%
myNewData.head()
# Out:
#           assignment_id  user_id  assistment_id  problem_id  original  \
# order_id
# 33022537         277618    64525          33139       51424         1
# 33022709         277618    64525          33150       51435         1
# 35450204         220674    70363          33159       51444         1
# 35450295         220674    70363          33110       51395         1
# 35450311         220674    70363          33196       51481         1
#
#           correct  attempt_count  ms_first_response  hint_count  hint_total  \
# order_id
# 33022537        1              1              32454           0           3
# 33022709        1              1               4922           0           3
# 35450204        0              2              25390           0           3
# 35450295        1              1               4859           0           3
# 35450311        0             14              19813           3           4
#
#           overlap_time  first_action
# order_id
# ...

# %%
myNewData.dtypes
# Out:
# assignment_id        int64
# user_id              int64
# assistment_id        int64
# problem_id           int64
# original             int64
# correct              int64
# attempt_count        int64
# ms_first_response    int64
# hint_count           int64
# hint_total           int64
# overlap_time         int64
# first_action         int64
# dtype: object

# %% [markdown]
# Feature scalling- Make the feuture be on a simillar scale

# %%
myNewData1=myNewData.loc[myNewData['user_id']==64525]

# %%
myNewData1.head()
# Out:
#           assignment_id  user_id  assistment_id  problem_id  original  \
# order_id
# 33022537         277618    64525          33139       51424         1
# 33022709         277618    64525          33150       51435         1
# 28186893         270591    64525          52640       92320         1
# 28187093         270591    64525          52655       92335         1
# 32413158         277547    64525          52647       92327         1
#
#           correct  attempt_count  ms_first_response  hint_count  hint_total  \
# order_id
# 33022537        1              1              32454           0           3
# 33022709        1              1               4922           0           3
# 28186893        1              1              45935           0           3
# 28187093        1              1              21618           0           3
# 32413158        1              1              28122           0           3
#
#           overlap_time  first_action
# order_id
# ...

# %%
myNewData.sort_values(by='problem_id').tail()
# Out:
#         assignment_id  user_id  assistment_id  problem_id  original  correct  \
# 507195         286705    87881         106206      207344         1        1
# 507196         286705    87881         106207      207345         1        1
# 507197         286705    87881         106208      207346         1        1
# 507198         286705    87881         106209      207347         1        1
# 507199         286705    87881         106210      207348         1        1
#
#         attempt_count  ms_first_response  hint_count  hint_total  \
# 507195              1               3741           0           0
# 507196              1               3798           0           0
# 507197              1               3090           0           0
# 507198              1               2436           0           0
# 507199              1               5370           0           0
#
#         overlap_time  first_action
# 507195          3741             0
# 507196          3798             0
# ...

# %%
print(myNewData.user_id.unique())
# Out:
# [64525 70363 70677 ... 91085 91086 91110]

# %%
myNewData.user_id.value_counts().sort_values(ascending=False)
# Out:
# 77899    8214
# 77118    6577
# 92246    4290
# 92249    3263
# 92250    2800
#          ...
# 81018       1
# 84305       1
# 81247       1
# 82770       1
# 81221       1
# Name: user_id, Length: 4217, dtype: int64

# %% [markdown]
# Remove students with less than 10 records

# %%
myNewDataless=(myNewData.user_id.value_counts()<=10)

# %%
myNewDataless
# Out:
# 77899    False
# 77118    False
# 92246    False
# 92249    False
# 92250    False
#          ...
# 92386     True
# 87800     True
# 71573     True
# 85867     True
# 81221     True
# Name: user_id, Length: 4217, dtype: bool

# %% [markdown]
# Drop values
